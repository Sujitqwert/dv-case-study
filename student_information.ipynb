# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujitqwert/dv-case-study/blob/main/student_information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  # Import seaborn for violin plots (requires installation)

# Load the dataset from the CSV file
df = pd.read_csv('/student information.csv')

# Create box plot for grades
plt.figure(figsize=(8, 6))
sns.boxplot(x='Grade', y='Test Score', data=df, order=['A', 'B', 'C', 'D', 'F'])
plt.title('Box Plot of Test Scores by Grade')
plt.xlabel('Grade')
plt.ylabel('Test Score')
plt.show()

# Create violin plot for grades
plt.figure(figsize=(8, 6))
sns.violinplot(x='Grade', y='Test Score', data=df, order=['A', 'B', 'C', 'D', 'F'])
plt.title('Violin Plot of Test Scores by Grade')
plt.xlabel('Grade')
plt.ylabel('Test Score')
plt.show()

# %% [markdown]
# # New Section
